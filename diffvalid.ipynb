# %% [markdown]
# ## Validation of diffusion equation

# %% [markdown]
# ### Analytical solution (1D)$ c(x,t) = \frac{n}{A\sqrt{\pi D t} } e^{-x^2/4Dt}$where A is area. Soln is  based on init. cond$c(0,0) = n$ and $c(x>0,0) = 0$which implies $dc/dx=0$.Using  $D =1\; um^2/ms$, $Dt = 0.1 um^2$, $t=0.1 ms$(compare with "Diffusion: the thermodynamic view" ppt file in papers (fig 21.26)

# %%
A=1.n=1.DRef=1e-9 # m^2/sDRef=1e3 # um^2/sDRef=1. # um^2/msx = np.linspace(0,2,100) # [um]t0=0.05 # [ms]# x [um]def cxt(x,t):    Dt = DRef*t    prefac = n/(A*np.sqrt(np.pi*Dt))    #prefac = 1.    exp = np.exp(-x*x/(4*Dt))    return prefac *expvfunc = np.vectorize(cxt,otypes=[float])

# %%
plt.plot(x,vfunc(x,t0),label="t=%4.2f [ms]"%t0)#plt.plot(x,np.exp(-x*x/(4*D*t)),label="t=%4.2f [s]"%t)t=0.1plt.plot(x,vfunc(x,t),label="t=%4.2f [ms]"%t)t=0.3plt.plot(x,vfunc(x,t),label="t=%4.2f [ms]"%t)t=1.0plt.plot(x,vfunc(x,t),label="t=%4.2f [ms]"%t)# evaluate at c(x,t) ~ 1/e (since 1/sqrt[pi*D*t]=1)t_oe = 1/np.pi*DRefplt.scatter(1,cxt(1,t), label="t=%4.2f [ms], c~1/e"%t_oe)plt.title("D=%3.1f [$\mu m^2/ms$]" % DRef)plt.xlabel("[$\mu m$]")plt.ylabel("c/(n/A)")plt.legend(loc=0)print cxt(1,t)print np.exp(-1)
# Out:
# 0.4393912894680.367879441171

# %% [markdown]
# ### Numerical solver

# %%
#%loadpy template_timedep.py

# %%
## Time dependent solver, single species # from dolfin import *# Nonlinear equation class MyEquation(NonlinearProblem):    def __init__(self, a, L):        NonlinearProblem.__init__(self)        self.L = L        self.a = a        self.reset_sparsity = True    def F(self, b, x):        assemble(self.L, tensor=b)    def J(self, A, x):        assemble(self.a, tensor=A, reset_sparsity=self.reset_sparsity)        self.reset_sparsity = False# D [um^2/ms]        def run(D=1.,x=x): #            ## params     Dp = Constant(D) # [um^2/ms]    dt=0.01 # [ms]      # Create mesh and define function space    # mesh = UnitCube(100,3,3)    mesh = UnitInterval(100)    mesh.coordinates()[:]*= np.max(x) # assuming x=[0,n]    V = FunctionSpace(mesh, "Lagrange", 1)        # Define trial and test functions    du    = TrialFunction(V)    q  = TestFunction(V)    # Define functions    u   = Function(V)  # current solution    u0  = Function(V)  # solution from previous converged step    print "WWARNING: this is a bit risky, since need to use dof mapping to relate u to x "     #init_cond = Expression("-x[0]")    xs = np.ndarray.flatten(mesh.coordinates())    u.vector()[:] = cxt(xs,t0)    u0.vector()[:] = cxt(xs,t0)    # weak form     RHS = -inner(Dp*grad(u), grad(q))*dx    L = u*q*dx - u0*q*dx - dt * RHS        # Compute directional derivative about u in the direction of du (Jacobian)    a = derivative(L, u, du)            problem = MyEquation(a,L)    solver = NewtonSolver("gmres")             #file = File("output.pvd", "compressed")    t = t0    T=t0+500*dt      #file << (u,t)     us=[]    ts=[]    while (t < T):        t += dt        u0.vector()[:] = u.vector()        solver.solve(problem, u.vector())        #    print u.vector()[0]        us.append(u.vector()[:])        ts.append(t)    us=np.asarray(us)    ts=np.asarray(ts)    return xs,us,ts        #print dt

# %% [markdown]
# ### Validation of numerical solution

# %%
xs,usRef,tsRef=run(D=DRef,x=x)#plt.plot(xs,np.asarray(u0.vector()))plt.plot(xs,cxt(xs,t0),label="t=%3.2f [ms] (init)"%t0)i=0plt.plot(xs,usRef[i,:],label="t=%3.2f"%tsRef[i])i=26plt.plot(xs,usRef[i,:],label="t=%3.2f"%tsRef[i])plt.plot(xs,cxt(xs,tsRef[i]),'k.',label="t=%3.2f  (analytical)"%tsRef[i])i=94plt.plot(xs,usRef[i,:],label="t=%3.2f"%tsRef[i])plt.legend()plt.title("Validation: D=%3.1f [$\mu m^2/ms$]" % DRef)plt.xlabel("[$\mu m^2$]")plt.ylabel("c/(n/A)")plt.legend(loc=0)plt.gcf().savefig("validationDiff.png")
# Out:
# WWARNING: this is a bit risky, since need to use dof mapping to relate u to x

# %% [markdown]
# ### Testing to see how fast diffusive wave arrives

# %%
xPosn =0.99cVal = np.exp(-1)xMididx = map(lambda x: x>xPosn, xs).index(True)

# %%
D0p1 = 0.1 # um^2/msxs,usD0p1,tsD0p1=run(D=D0p1,x=x)#plt.plot(xs,np.asarray(u0.vector()))i=50plt.plot(xs,usD0p1[i,:],label="t=%3.2f, D=%3.1f"%(tsD0p1[i],D0p1))plt.plot(xs,usRef[i,:],label="t=%3.2f, D=%3.1f"%(tsRef[i],DRef))plt.legend()plt.title("D=%3.1f [$\mu m^2/ms$]" % D0p1)plt.xlabel("[$\mu m^2$]")plt.ylabel("c/(n/A)")plt.legend(loc=0)
# Out:
# WWARNING: this is a bit risky, since need to use dof mapping to relate u to x

# %%
cVal = 0.49Di=1.xs,us,ts=run(D=Di,x=x)overThresh=map(lambda x: x>cVal, us[:,xMididx]).index(True)print ts[overThresh]plt.plot(xs,us[overThresh,:],label="t=%3.2f, D=%3.1f"%(ts[overThresh],Di))Di = 0.5xs,us,ts=run(D=Di,x=x)overThresh=map(lambda x: x>cVal, us[:,xMididx]).index(True)print ts[overThresh]plt.plot(xs,us[overThresh,:],label="t=%3.2f, D=%3.1f"%(ts[overThresh],Di))Di=0.1xs,us,ts=run(D=Di,x=x)overThresh=map(lambda x: x>cVal, us[:,xMididx]).index(True)print ts[overThresh]plt.plot(xs,us[overThresh,:],label="t=%3.2f, D=%3.1f"%(ts[overThresh],Di))plt.plot(x[xMididx],cVal,'k.',label="Thresh")plt.ylim([0,2.5])plt.legend()
# Out:
# WWARNING: this is a bit risky, since need to use dof mapping to relate u to x 0.49
# WWARNING: this is a bit risky, since need to use dof mapping to relate u to x 0.91
# WWARNING: this is a bit risky, since need to use dof mapping to relate u to x 4.24
